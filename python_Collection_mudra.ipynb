# %%
d = {}

# %%
d.setdefault('name')

# %%
d.update({'name': 'mudra'})

# %%
d
# Out:
# {'name': 'mudra'}

# %%
d.update({'maths': 85, 'english': 98, 'science': 79, 'social': 87, 'computer': 99 })

# %%
d
# Out:
# {'computer': 99,
#  'english': 98,
#  'maths': 85,
#  'name': 'mudra',
#  'science': 79,
#  'social': 87}

# %%
d.update({'mudra': [25,58,69,57,96]})

# %%
d
# Out:
# {'computer': 99,
#  'english': 98,
#  'maths': 85,
#  'mudra': [25, 58, 69, 57, 96],
#  'name': 'mudra',
#  'science': 79,
#  'social': 87}

# %%
d.pop('computer')
# Out:
# 99

# %%
d.pop('english')
# Out:
# 98

# %%
d.pop('maths')
# Out:
# 85

# %%
d.pop('name')
# Out:
# 'mudra'

# %%
d
# Out:
# {'mudra': [25, 58, 69, 57, 96], 'science': 79, 'social': 87}

# %%
d.pop('science')
# Out:
# 79

# %%
d.pop('social')
# Out:
# 87

# %%
d.update({'nirali': [25,89,56,57,96]})

# %%
d.update({'hritika': [25,58,69,57,96]})

# %%
d.update({'roman': [25,58,69,57,96]})

# %%
d.update({'meghdeep': [25,58,69,57,96]})

# %%
d
# Out:
# {'hritika': [25, 58, 69, 57, 96],
#  'meghdeep': [25, 58, 69, 57, 96],
#  'mudra': [25, 58, 69, 57, 96],
#  'nirali': [25, 58, 69, 57, 96],
#  'roman': [25, 58, 69, 57, 96]}

# %%
for i in d:
  print(i, d[i])
# Out:
# mudra [25, 58, 69, 57, 96]
# nirali [25, 58, 69, 57, 96]
# hritika [25, 58, 69, 57, 96]
# roman [25, 58, 69, 57, 96]
# meghdeep [25, 58, 69, 57, 96]

# %%
e={}

# %%
e = {'mudra':{'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87},
   'nirali':{'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87},
   'hritika':{'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87},
   'roman':{'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87},
   'meghdeeep':{'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87}}

# %%
e
# Out:
# {'hritika': {'computer': 99,
#   'english': 95,
#   'maths': 32,
#   'science': 87,
#   'social': 89},
#  'meghdeeep': {'computer': 99,
#   'english': 95,
#   'maths': 32,
#   'science': 87,
#   'social': 89},
#  'mudra': {'computer': 99,
#   'english': 95,
#   'maths': 32,
#   'science': 87,
#   'social': 89},
#  'nirali': {'computer': 99,
#   'english': 95,
#   'maths': 32,
#   'science': 87,
#   'social': 89},
#  'roman': {'computer': 99,
#   'english': 95,
#   'maths': 32,
#   'science': 87,
#   'social': 89}}

# %%
d={}

# %%
d = [{'name': 'mudra', 'class': 10, 'subjects':{'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87}},
   {'name': 'nirali', 'class': 7, 'subjects':{'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87}},
   {'name': 'hritika', 'class': 8, 'subjects':{'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87}},
   {'name': 'roman', 'class': 9, 'subjects':{'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87}},
   {'name': 'meghdeeep', 'class': 6, 'subjects':{'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87}}]

# %%
d
# Out:
# [{'class': 10,
#   'name': 'mudra',
#   'subjects': {'computer': 99,
#    'english': 95,
#    'maths': 32,
#    'science': 87,
#    'social': 89}},
#  {'class': 7,
#   'name': 'nirali',
#   'subjects': {'computer': 99,
#    'english': 95,
#    'maths': 32,
#    'science': 87,
#    'social': 89}},
#  {'class': 8,
#   'name': 'hritika',
#   'subjects': {'computer': 99,
#    'english': 95,
#    'maths': 32,
#    'science': 87,
#    'social': 89}},
#  {'class': 9,
#   'name': 'roman',
#   'subjects': {'computer': 99,
#    'english': 95,
#    'maths': 32,
#    'science': 87,
#    'social': 89}},
#  {'class': 6,
#   'name': 'meghdeeep',
#   'subjects': {'computer': 99,
#    'english': 95,
#    'maths': 32,
#    'science': 87,
#    'social': 89}}]

# %%
type(d)
# Out:
# list

# %%
for i in d:
  print(i)
# Out:
# {'name': 'mudra', 'class': 10, 'subjects': {'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87}}
# {'name': 'nirali', 'class': 7, 'subjects': {'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87}}
# {'name': 'hritika', 'class': 8, 'subjects': {'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87}}
# {'name': 'roman', 'class': 9, 'subjects': {'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87}}
# {'name': 'meghdeeep', 'class': 6, 'subjects': {'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87}}

# %%
for item in d:
  for i in item:
    if item['class'] == 10:
      print(i, item[i])
# Out:
# name mudra
# class 10
# subjects {'maths': 32, 'english': 95, 'social': 89, 'computer': 99, 'science': 87}

# %%
cls = 10
for item in d:
  for i in item:
    if item[i] == cls:
      print('name', item['name'])
      print(i, item[i])
      print('MARKS')
      for s in item['subjects']:
        print(s, item['subjects'][s])
# Out:
# name mudra
# class 10
# MARKS
# maths 32
# english 95
# social 89
# computer 99
# science 87

# %%
for item in d:
  for i in item:
      print('name', item['name'])
      print(i, item[i])
      for cls in d:
        print('class', d['class'])
        print(cls, d[cls])
        print('MARKS')
        for s in item['subjects']:
         print(s, item['subjects'][s])
# Out:
# name mudra
# name mudra
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-6ff4d2586fe2> in <module>()
#       4       print(i, item[i])
#       5       for cls in d:
# ----> 6         print('class', d['class'])
#       7         print(cls, d[cls])
#       8         print('MARKS')
#
# TypeError: list indices must be integers or slices, not str

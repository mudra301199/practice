# %%
n = input('enter any year: ')

if n.isnumeric():
  if int(n) % 4 == 0:
    print('year is leap year')
  else:
    print('year is not a leap year')
else:
  print('please enter year only.')
# Out:
# year is leap year

# %%
n = input('enter marks of English: ')
o = input('enter marks of Maths: ')

if n.isnumeric():
  if o.isnumeric():
   if int(n + o) // 2 >= 90:
     print('Excellent')
   elif int(n + o) // 2 >= 75:
       print('Very Good')
   elif int(n + o) // 2 >= 50:
         print('Good')
   elif int(n + o) // 2 == 35:
           print('Average')
else:
 print('Fail')
# Out:
# enter marks of English: 95
# enter marks of Maths: 90
# Excellent

# %%
a = 18
n = input('Enter your age:')

if n.isnumeric():
  if int(n) >= 18:
    print('You are allowed to enter')
  else:
      print('come back after')

# %%
n = int(input("Enter your number between 1 to 20 "))
for i in range(21):
    if n == i:
      print("You have won")
      break
else:
   print("better luck next time")
# Out:
# Enter your number between 1 to 20 26
# better luck next time

# %%
n = int(input("Enter your number between 1 to 20 "))
n1 = int(input("Enter your number between 1 to 20 "))
n2 = int(input("Enter your number between 1 to 20 "))
for i in range(21):
  if n and n1 and n2 == i:
    print("You have won")
    break
else:
    print("better luck next time")

# %%
n = [1,2,3,4,5]
n[::-1]
# Out:
# [5, 4, 3, 2, 1]

# %%
class HelloWorld:
  name = 'helloworld'

# %%
o = HelloWorld()

# %%
o.name
# Out:
# 'helloworld'

# %%
o.continent = 'Asia'

# %%
o.country = 'India'

# %%
o.state = 'Gujarat'

# %%
o.city = 'Ahmedabad'

# %%
print(dir(o))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'city', 'continent', 'country', 'name', 'state']

# %%
o.__dict__
# Out:
# {'city': 'Ahmedabad',
#  'continent': 'Asia',
#  'country': 'India',
#  'state': 'Gujarat'}

# %%
o.HelloWorld
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-8c8d01aa1d23> in <module>()
# ----> 1 o.HelloWorld
#
# AttributeError: type object 'Calc' has no attribute 'HelloWorld'

# %%
class Calc:
  def add(*self):
    return sum(self)

# %%
o = Calc

# %%
o.add(1,4,5,6,7,8,9)
# Out:
# 40

# %%
class Bank:
  def bank(self):
    print("Welcome to Mudra Bank")
  
class Nirali(Bank):
  def details(self):
    Bank.bank(self)
    acc_no = 24646
    print('acc_no = 24646')
    pin = 4567
    print('pin = 4567')
    balance = 10000
    print('balance = 10000')
    holder_name = 'Nirali'
    print('holder_name = Nirali')

class Hritika(Bank):
  def details(self):
    Bank.bank(self)
    acc_no = 24647
    print('acc_no = 24647')
    pin = 3456
    print('pin = 3456')
    balance = 50000
    print('balance = 50000')
    holder_name = 'Hritika'
    print('holder_name = Hritika')

# %%
o = Bank()

# %%
o.bank()
# Out:
# Welcome to Mudra Bank

# %%
o = Nirali()
p = Hritika()

# %%
o.details()
p.details()
# Out:
# Welcome to Mudra Bank
# acc_no = 24646
# pin = 4567
# balance = 10000
# holder_name = Nirali
# Welcome to Mudra Bank
# acc_no = 24647
# pin = 3456
# balance = 50000
# holder_name = Hritika

# %%
acc_no = input('enter account no.: ')

if acc_no.isnumeric():
  acc_no = int(acc_no)
  if acc_no == bank['acc_no']:
    print(f'welcome {bank["holder_name"]}!')
    pin = input('enter your pin: ')
    if pin.isnumeric():
      pin = int(pin)
      if pin == bank['pin']:
        print(f"Your account balance is {bank['balance']}")
      else:
        raise Exception('incorrect pin.')
    else:
      raise Exception('wrong input')
  else:
    raise Exception('wrong account no.')
else:
  raise Exception('wrong input')
# Out:
# enter account no.: 24646
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-358089ed7f44> in <module>()
#       3 if acc_no.isnumeric():
#       4   acc_no = int(acc_no)
# ----> 5   if acc_no == bank['acc_no']:
#       6     print(f'welcome {bank["holder_name"]}!')
#       7     pin = input('enter your pin: ')
#
# NameError: name 'bank' is not defined

# %%
class bank:
    def __init__(self):
        self.balance=0
        print("Welcome")
 
    def deposit(self):
        amount=float(input("Enter amount to be Deposited: "))
        self.balance += amount
        print("\n Deposited:",amount)
        print("\n Available Balance=",self.balance)
 
    def withdraw(self):
        amount = float(input("Enter amount to be Withdrawn: "))
        if self.balance>=amount:
            self.balance -= amount
            print("\n Withdrew:", amount)
            print("\n Available Balance=",self.balance)
        else:
            print("\n Insufficient balance  ")
            print("\n Available Balance=",self.balance)

# %%
o=bank()
# Out:
# Welcome

# %%
o.deposit()
# Out:
# Enter amount to be Deposited: 5000
#
#  Deposited: 5000.0
#
#  Available Balance= 5000.0

# %%
o.withdraw()
# Out:
# Enter amount to be Withdrawn: 10000
#
#  Insufficient balance
#
#  Available Balance= 4000.0
